# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
drugs= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Drogas/drugs.csv')
drugs.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
drugs.shape
# Out:
# (200, 6)

# %%
drugs.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
drugs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
print(f'''Drugs: {drugs['Drug'].unique()}, 
Sex: {drugs['Sex'].unique()}
Blood Pressure: {drugs['BP'].unique()}
Cholesterol: {drugs['Cholesterol'].unique()}''')
# Out:
# Drugs: ['DrugY' 'drugC' 'drugX' 'drugA' 'drugB'],
# Sex: ['F' 'M']
# Blood Pressure: ['HIGH' 'LOW' 'NORMAL']
# Cholesterol: ['HIGH' 'NORMAL']

# %%
drugs = drugs.replace({'Sex':{'F':0, 'M':1}, 
                     'Cholesterol':{'NORMAL':0, 'HIGH':1},
                    'BP':{'LOW':0,'NORMAL':1, 'HIGH':2},
                    'Drug':{'drugA':0, 'drugB':1,'drugC':2,'drugX':3, 'DrugY':4 }})
drugs
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0     23    0   2            1   25.355     4
# 1     47    1   0            1   13.093     2
# 2     47    1   0            1   10.114     2
# 3     28    0   1            1    7.798     3
# 4     61    0   0            1   18.043     4
# ..   ...  ...  ..          ...      ...   ...
# 195   56    0   0            1   11.567     2
# 196   16    1   0            1   12.006     2
# 197   52    1   1            1    9.894     3
# 198   23    1   1            0   14.020     3
# 199   40    0   0            0   11.349     3
#
# [200 rows x 6 columns]

# %%
X = drugs.drop('Drug', axis=1)
y= drugs['Drug']

# %%
X.shape
# Out:
# (200, 5)

# %%
y.shape
# Out:
# (200,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42, test_size = 0.3)

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
result = model.score(X_test, y_test)
print(f'Accuracy: {(result * 100):.2f}%')
# Out:
# Accuracy: 96.67%

# %%
X_test.shape
# Out:
# (60, 5)

# %%
predict = model.predict(X_test[40:50])
predict
# Out:
# array([3, 3, 3, 4, 4, 2, 4, 4, 1, 3])
